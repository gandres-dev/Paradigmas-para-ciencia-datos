# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import KElbowVisualizer

# Generate synthetic dataset with 8 random clusters
X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(4,12))

visualizer.fit(X)        # Fit the data to the visualizer
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# KElbowVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f45edd7ea90>,
#                  k=None, metric=None, model=None, timings=True)

# %% [markdown]
# y de azul, es enumero de elementos del grupo mayor.
#
# https://www.scikit-yb.org/en/latest/api/cluster/elbow.html

# %% [markdown]
# ## Otro ejemplo

# %%
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
plt.rcParams('figure.figsize') = (12, 9)

# %%
X, y = make_blobs(n_samples=900, n_features=3, centers=4)
fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(X[:,0], X[:,1], X[:,2])

# %%
kmeans = KMeans(n_clusters=4)
kmeans = kmeans.fit(X)
y_hat = kmeans.predict(X)
C = kmeans.cluster_centers_

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0], X[:,1], X[:,2], c=y_hat)
ax.scatter(C[:,0], C[:,1], C[:,2],  marker='*', s=100)
